# %% [markdown]
# ### Install Python Packages

# %%
### Create or update your local Python environment

# %pip install azure-functions
# %pip install azure-core
# %pip install azure-cosmos
# %pip install openai
# %pip install numpy
# %pip install requests
# %pip install pandas
# %pip install azure-storage-blob 
# %pip install azure-identity
# %pip install smart_open
# %pip install tenacity
# %pip install pinecone-client
# %pip install redis
# %pip install tiktoken
# %pip install azure-storage-file-share
# %pip install python-dotenv
# %pip install azure-search-documents==11.4.0b3
# %pip install azure-ai-formrecognizer
# %pip install beautifulsoup4
# %pip install lxml
# %pip install openpyxl
# %pip install azure-ai-textanalytics
# %pip install langchain==0.0.139
# %pip install flask
# %pip install flask-socketio
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting azure-functions
#   Downloading azure_functions-1.17.0-py3-none-any.whl (165 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.8/165.8 kB 3.1 MB/s eta 0:00:0000:01
# Installing collected packages: azure-functions
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed azure-functions-1.17.0
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting azure-core
#   Downloading azure_core-1.29.4-py3-none-any.whl (192 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 192.4/192.4 kB 1.9 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.9/site-packages (from azure-core) (1.16.0)
# Collecting requests>=2.18.4
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting typing-extensions>=4.6.0
#   Using cached typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.2.0-cp39-cp39-macosx_10_9_x86_64.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.4/126.4 kB 2.8 MB/s eta 0:00:00a 0:00:01
# Collecting urllib3<3,>=1.21.1
#   Downloading urllib3-2.0.4-py3-none-any.whl (123 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 123.9/123.9 kB 3.7 MB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->azure-core) (3.3)
# Collecting certifi>=2017.4.17
#   Downloading certifi-2023.7.22-py3-none-any.whl (158 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 3.7 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: urllib3, typing-extensions, charset-normalizer, certifi, requests, azure-core
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.0.1
#     Uninstalling typing_extensions-4.0.1:
#       Successfully uninstalled typing_extensions-4.0.1
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed azure-core-1.29.4 certifi-2023.7.22 charset-normalizer-3.2.0 requests-2.31.0 typing-extensions-4.7.1 urllib3-2.0.4
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting azure-cosmos
#   Downloading azure_cosmos-4.5.0-py3-none-any.whl (226 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.5/226.5 kB 3.2 MB/s eta 0:00:0000:01
# Requirement already satisfied: azure-core<2.0.0,>=1.23.0 in /usr/local/lib/python3.9/site-packages (from azure-cosmos) (1.29.4)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.23.0->azure-cosmos) (4.7.1)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.23.0->azure-cosmos) (2.31.0)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.23.0->azure-cosmos) (1.16.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.0->azure-cosmos) (2.0.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.0->azure-cosmos) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.0->azure-cosmos) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.0->azure-cosmos) (2023.7.22)
# Installing collected packages: azure-cosmos
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed azure-cosmos-4.5.0
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting openai
#   Downloading openai-0.28.0-py3-none-any.whl (76 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.9/site-packages (from openai) (2.31.0)
# Collecting tqdm
#   Downloading tqdm-4.66.1-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 1.7 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.9/site-packages (from openai) (3.7.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests>=2.20->openai) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.9/site-packages (from requests>=2.20->openai) (3.2.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests>=2.20->openai) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests>=2.20->openai) (3.3)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/site-packages (from aiohttp->openai) (21.2.0)
# Requirement already satisfied: chardet<4.0,>=2.0 in /usr/local/lib/python3.9/site-packages (from aiohttp->openai) (3.0.4)
# Requirement already satisfied: async-timeout<4.0,>=3.0 in /usr/local/lib/python3.9/site-packages (from aiohttp->openai) (3.0.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/site-packages (from aiohttp->openai) (5.2.0)
# Requirement already satisfied: typing-extensions>=3.6.5 in /usr/local/lib/python3.9/site-packages (from aiohttp->openai) (4.7.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/site-packages (from aiohttp->openai) (1.7.2)
# Installing collected packages: tqdm, openai
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed openai-0.28.0 tqdm-4.66.1
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: numpy in /usr/local/lib/python3.9/site-packages (1.21.4)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: requests in /usr/local/lib/python3.9/site-packages (2.31.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests) (3.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.9/site-packages (from requests) (3.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests) (2023.7.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests) (2.0.4)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting pandas
#   Downloading pandas-2.1.0-cp39-cp39-macosx_10_9_x86_64.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 12.9 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.9/site-packages (from pandas) (2.8.2)
# Collecting tzdata>=2022.1
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Collecting pytz>=2020.1
#   Downloading pytz-2023.3.post1-py2.py3-none-any.whl (502 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.5/502.5 kB 8.2 MB/s eta 0:00:0000:01
# Collecting numpy>=1.22.4
#   Downloading numpy-1.25.2-cp39-cp39-macosx_10_9_x86_64.whl (20.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.8/20.8 MB 11.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Installing collected packages: pytz, tzdata, numpy, pandas
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.4
#     Uninstalling numpy-1.21.4:
#       Successfully uninstalled numpy-1.21.4
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed numpy-1.25.2 pandas-2.1.0 pytz-2023.3.post1 tzdata-2023.3
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting azure-storage-blob
#   Downloading azure_storage_blob-12.17.0-py3-none-any.whl (388 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.0/388.0 kB 1.7 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: azure-core<2.0.0,>=1.28.0 in /usr/local/lib/python3.9/site-packages (from azure-storage-blob) (1.29.4)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.9/site-packages (from azure-storage-blob) (4.7.1)
# Collecting cryptography>=2.1.4
#   Downloading cryptography-41.0.3-cp37-abi3-macosx_10_12_x86_64.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 12.3 MB/s eta 0:00:0000:0100:01
# Collecting isodate>=0.6.1
#   Using cached isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob) (1.16.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2.31.0)
# Collecting cffi>=1.12
#   Downloading cffi-1.15.1-cp39-cp39-macosx_10_9_x86_64.whl (179 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.2/179.2 kB 5.1 MB/s eta 0:00:00
# Collecting pycparser
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2023.7.22)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (2.0.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.28.0->azure-storage-blob) (3.2.0)
# Installing collected packages: pycparser, isodate, cffi, cryptography, azure-storage-blob
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   Attempting uninstall: isodate
#     Found existing installation: isodate 0.6.0
#     Uninstalling isodate-0.6.0:
#       Successfully uninstalled isodate-0.6.0
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed azure-storage-blob-12.17.0 cffi-1.15.1 cryptography-41.0.3 isodate-0.6.1 pycparser-2.21
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting azure-identity
#   Downloading azure_identity-1.14.0-py3-none-any.whl (160 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 160.2/160.2 kB 1.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: cryptography>=2.5 in /usr/local/lib/python3.9/site-packages (from azure-identity) (41.0.3)
# Collecting msal<2.0.0,>=1.20.0
#   Downloading msal-1.23.0-py2.py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.8/90.8 kB 2.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: azure-core<2.0.0,>=1.11.0 in /usr/local/lib/python3.9/site-packages (from azure-identity) (1.29.4)
# Collecting msal-extensions<2.0.0,>=0.3.0
#   Using cached msal_extensions-1.0.0-py2.py3-none-any.whl (19 kB)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.11.0->azure-identity) (1.16.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.11.0->azure-identity) (2.31.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.11.0->azure-identity) (4.7.1)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.9/site-packages (from cryptography>=2.5->azure-identity) (1.15.1)
# Collecting PyJWT[crypto]<3,>=1.0.0
#   Downloading PyJWT-2.8.0-py3-none-any.whl (22 kB)
# Collecting portalocker<3,>=1.0
#   Using cached portalocker-2.7.0-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=2.5->azure-identity) (2.21)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.11.0->azure-identity) (3.2.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.11.0->azure-identity) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.11.0->azure-identity) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.11.0->azure-identity) (3.3)
# Installing collected packages: PyJWT, portalocker, msal, msal-extensions, azure-identity
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed PyJWT-2.8.0 azure-identity-1.14.0 msal-1.23.0 msal-extensions-1.0.0 portalocker-2.7.0
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting smart_open
#   Downloading smart_open-6.4.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 483.0 kB/s eta 0:00:00a 0:00:01
# Installing collected packages: smart_open
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed smart_open-6.4.0
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting tenacity
#   Downloading tenacity-8.2.3-py3-none-any.whl (24 kB)
# Installing collected packages: tenacity
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed tenacity-8.2.3
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting pinecone-client
#   Downloading pinecone_client-2.2.2-py3-none-any.whl (179 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 179.1/179.1 kB 1.1 MB/s eta 0:00:00a 0:00:01
# Collecting pyyaml>=5.4
#   Downloading PyYAML-6.0.1-cp39-cp39-macosx_10_9_x86_64.whl (197 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 197.8/197.8 kB 3.2 MB/s eta 0:00:0000:01
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.9/site-packages (from pinecone-client) (2.31.0)
# Collecting loguru>=0.5.0
#   Downloading loguru-0.7.2-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 1.4 MB/s eta 0:00:00:00:01
# Requirement already satisfied: typing-extensions>=3.7.4 in /usr/local/lib/python3.9/site-packages (from pinecone-client) (4.7.1)
# Collecting dnspython>=2.0.0
#   Downloading dnspython-2.4.2-py3-none-any.whl (300 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 5.8 MB/s eta 0:00:0000:01
# Requirement already satisfied: tqdm>=4.64.1 in /usr/local/lib/python3.9/site-packages (from pinecone-client) (4.66.1)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.9/site-packages (from pinecone-client) (2.0.4)
# Requirement already satisfied: numpy>=1.22.0 in /usr/local/lib/python3.9/site-packages (from pinecone-client) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.9/site-packages (from pinecone-client) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/site-packages (from python-dateutil>=2.5.3->pinecone-client) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.9/site-packages (from requests>=2.19.0->pinecone-client) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests>=2.19.0->pinecone-client) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests>=2.19.0->pinecone-client) (2023.7.22)
# Installing collected packages: pyyaml, loguru, dnspython, pinecone-client
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed dnspython-2.4.2 loguru-0.7.2 pinecone-client-2.2.2 pyyaml-6.0.1
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting redis
#   Downloading redis-5.0.0-py3-none-any.whl (250 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.1/250.1 kB 1.4 MB/s eta 0:00:0000:0100:01
# Collecting async-timeout>=4.0.2
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Installing collected packages: async-timeout, redis
#   Attempting uninstall: async-timeout
#     Found existing installation: async-timeout 3.0.1
#     Uninstalling async-timeout-3.0.1:
#       Successfully uninstalled async-timeout-3.0.1
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# aiohttp 3.7.4 requires async-timeout<4.0,>=3.0, but you have async-timeout 4.0.3 which is incompatible.
# Successfully installed async-timeout-4.0.3 redis-5.0.0
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting tiktoken
#   Downloading tiktoken-0.4.0-cp39-cp39-macosx_10_9_x86_64.whl (798 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 798.2/798.2 kB 3.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.9/site-packages (from tiktoken) (2.31.0)
# Collecting regex>=2022.1.18
#   Downloading regex-2023.8.8-cp39-cp39-macosx_10_9_x86_64.whl (294 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.9/294.9 kB 10.5 MB/s eta 0:00:00
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (3.2.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests>=2.26.0->tiktoken) (3.3)
# Installing collected packages: regex, tiktoken
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed regex-2023.8.8 tiktoken-0.4.0
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting azure-storage-file-share
#   Downloading azure_storage_file_share-12.13.0-py3-none-any.whl (266 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.1/266.1 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.9/site-packages (from azure-storage-file-share) (4.7.1)
# Requirement already satisfied: azure-core<2.0.0,>=1.28.0 in /usr/local/lib/python3.9/site-packages (from azure-storage-file-share) (1.29.4)
# Requirement already satisfied: cryptography>=2.1.4 in /usr/local/lib/python3.9/site-packages (from azure-storage-file-share) (41.0.3)
# Requirement already satisfied: isodate>=0.6.1 in /usr/local/lib/python3.9/site-packages (from azure-storage-file-share) (0.6.1)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-file-share) (1.16.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.28.0->azure-storage-file-share) (2.31.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.9/site-packages (from cryptography>=2.1.4->azure-storage-file-share) (1.15.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.9/site-packages (from cffi>=1.12->cryptography>=2.1.4->azure-storage-file-share) (2.21)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.28.0->azure-storage-file-share) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.28.0->azure-storage-file-share) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.28.0->azure-storage-file-share) (2023.7.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.28.0->azure-storage-file-share) (3.2.0)
# Installing collected packages: azure-storage-file-share
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed azure-storage-file-share-12.13.0
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.9/site-packages (0.19.2)
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting azure-search-documents==11.4.0b3
#   Downloading azure_search_documents-11.4.0b3-py3-none-any.whl (296 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 1.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: isodate>=0.6.0 in /usr/local/lib/python3.9/site-packages (from azure-search-documents==11.4.0b3) (0.6.1)
# Requirement already satisfied: azure-core<2.0.0,>=1.24.0 in /usr/local/lib/python3.9/site-packages (from azure-search-documents==11.4.0b3) (1.29.4)
# Collecting azure-common~=1.1
#   Using cached azure_common-1.1.28-py2.py3-none-any.whl (14 kB)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.24.0->azure-search-documents==11.4.0b3) (2.31.0)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.24.0->azure-search-documents==11.4.0b3) (4.7.1)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.24.0->azure-search-documents==11.4.0b3) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.24.0->azure-search-documents==11.4.0b3) (3.2.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.24.0->azure-search-documents==11.4.0b3) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.24.0->azure-search-documents==11.4.0b3) (2023.7.22)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.24.0->azure-search-documents==11.4.0b3) (3.3)
# Installing collected packages: azure-common, azure-search-documents
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed azure-common-1.1.28 azure-search-documents-11.4.0b3
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting azure-ai-formrecognizer
#   Downloading azure_ai_formrecognizer-3.3.0-py3-none-any.whl (297 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 297.8/297.8 kB 1.5 MB/s eta 0:00:0000:0100:01
# Collecting msrest>=0.6.21
#   Using cached msrest-0.7.1-py3-none-any.whl (85 kB)
# Requirement already satisfied: azure-core<2.0.0,>=1.23.0 in /usr/local/lib/python3.9/site-packages (from azure-ai-formrecognizer) (1.29.4)
# Requirement already satisfied: azure-common~=1.1 in /usr/local/lib/python3.9/site-packages (from azure-ai-formrecognizer) (1.1.28)
# Requirement already satisfied: typing-extensions>=4.0.1 in /usr/local/lib/python3.9/site-packages (from azure-ai-formrecognizer) (4.7.1)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (1.16.0)
# Requirement already satisfied: requests>=2.18.4 in /usr/local/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (2.31.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from msrest>=0.6.21->azure-ai-formrecognizer) (2023.7.22)
# Collecting requests-oauthlib>=0.5.0
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: isodate>=0.6.0 in /usr/local/lib/python3.9/site-packages (from msrest>=0.6.21->azure-ai-formrecognizer) (0.6.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (2.0.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.23.0->azure-ai-formrecognizer) (3.2.0)
# Collecting oauthlib>=3.0.0
#   Using cached oauthlib-3.2.2-py3-none-any.whl (151 kB)
# Installing collected packages: oauthlib, requests-oauthlib, msrest, azure-ai-formrecognizer
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed azure-ai-formrecognizer-3.3.0 msrest-0.7.1 oauthlib-3.2.2 requests-oauthlib-1.3.1
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting beautifulsoup4
#   Using cached beautifulsoup4-4.12.2-py3-none-any.whl (142 kB)
# Collecting soupsieve>1.2
#   Downloading soupsieve-2.5-py3-none-any.whl (36 kB)
# Installing collected packages: soupsieve, beautifulsoup4
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed beautifulsoup4-4.12.2 soupsieve-2.5
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.5/124.5 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.9/site-packages (from langchain==0.0.139) (1.25.2)
# Collecting openapi-schema-pydantic<2.0,>=1.2
#   Using cached openapi_schema_pydantic-1.2.4-py3-none-any.whl (90 kB)
# Collecting pydantic<2,>=1
#   Downloading pydantic-1.10.12-cp39-cp39-macosx_10_9_x86_64.whl (2.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 21.8 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.9/site-packages (from langchain==0.0.139) (4.0.3)
# Requirement already satisfied: PyYAML>=5.4.1 in /usr/local/lib/python3.9/site-packages (from langchain==0.0.139) (6.0.1)
# Collecting dataclasses-json<0.6.0,>=0.5.7
#   Downloading dataclasses_json-0.5.14-py3-none-any.whl (26 kB)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.139) (3.2.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.139) (1.7.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.139) (21.2.0)
# Collecting aiosignal>=1.1.2
#   Using cached aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.4.0-cp39-cp39-macosx_10_9_x86_64.whl (47 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 kB 1.3 MB/s eta 0:00:00
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.9/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain==0.0.139) (5.2.0)
# Collecting typing-inspect<1,>=0.4.0
#   Using cached typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Collecting marshmallow<4.0.0,>=3.18.0
#   Downloading marshmallow-3.20.1-py3-none-any.whl (49 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 1.7 MB/s eta 0:00:00
# Collecting cachetools
#   Downloading cachetools-5.3.1-py3-none-any.whl (9.3 kB)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.9/site-packages (from pydantic<2,>=1->langchain==0.0.139) (4.7.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/site-packages (from requests<3,>=2->langchain==0.0.139) (3.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.9/site-packages (from requests<3,>=2->langchain==0.0.139) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/site-packages (from requests<3,>=2->langchain==0.0.139) (2023.7.22)
# Collecting greenlet!=0.4.17
#   Downloading greenlet-2.0.2-cp39-cp39-macosx_11_0_x86_64.whl (241 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 241.4/241.4 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.9/site-packages (from marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.139) (21.3)
# Collecting mypy-extensions>=0.3.0
#   Using cached mypy_extensions-1.0.0-py3-none-any.whl (4.7 kB)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.9/site-packages (from packaging>=17.0->marshmallow<4.0.0,>=3.18.0->dataclasses-json<0.6.0,>=0.5.7->langchain==0.0.139) (3.0.6)
# Installing collected packages: pydantic, mypy-extensions, greenlet, frozenlist, cachetools, typing-inspect, SQLAlchemy, openapi-schema-pydantic, marshmallow, gptcache, aiosignal, dataclasses-json, aiohttp, langchain
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   Attempting uninstall: aiohttp
#     Found existing installation: aiohttp 3.7.4
#     Uninstalling aiohttp-3.7.4:
#       Successfully uninstalled aiohttp-3.7.4
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gremlinpython 3.5.1 requires aiohttp<=3.7.4,>=3.7.0, but you have aiohttp 3.8.5 which is incompatible.
# Successfully installed SQLAlchemy-1.4.49 aiohttp-3.8.5 aiosignal-1.3.1 cachetools-5.3.1 dataclasses-json-0.5.14 frozenlist-1.4.0 gptcache-0.1.40 greenlet-2.0.2 langchain-0.0.139 marshmallow-3.20.1 mypy-extensions-1.0.0 openapi-schema-pydantic-1.2.4 pydantic-1.10.12 typing-inspect-0.9.0
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting flask
#   Downloading flask-2.3.3-py3-none-any.whl (96 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.1/96.1 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: importlib-metadata>=3.6.0 in /Users/maitreyi/Library/Python/3.9/lib/python/site-packages (from flask) (6.8.0)
# Collecting click>=8.1.3
#   Downloading click-8.1.7-py3-none-any.whl (97 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 97.9/97.9 kB 2.2 MB/s eta 0:00:00ta 0:00:01
# Collecting blinker>=1.6.2
#   Downloading blinker-1.6.2-py3-none-any.whl (13 kB)
# Collecting itsdangerous>=2.1.2
#   Using cached itsdangerous-2.1.2-py3-none-any.whl (15 kB)
# Collecting Jinja2>=3.1.2
#   Using cached Jinja2-3.1.2-py3-none-any.whl (133 kB)
# Collecting Werkzeug>=2.3.7
#   Downloading werkzeug-2.3.7-py3-none-any.whl (242 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 242.2/242.2 kB 4.0 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: zipp>=0.5 in /Users/maitreyi/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=3.6.0->flask) (3.16.2)
# Collecting MarkupSafe>=2.0
#   Downloading MarkupSafe-2.1.3-cp39-cp39-macosx_10_9_x86_64.whl (13 kB)
# Installing collected packages: MarkupSafe, itsdangerous, click, blinker, Werkzeug, Jinja2, flask
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed Jinja2-3.1.2 MarkupSafe-2.1.3 Werkzeug-2.3.7 blinker-1.6.2 click-8.1.7 flask-2.3.3 itsdangerous-2.1.2
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Collecting flask-socketio
#   Downloading Flask_SocketIO-5.3.6-py3-none-any.whl (18 kB)
# Collecting python-socketio>=5.0.2
#   Downloading python_socketio-5.9.0-py3-none-any.whl (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 1.4 MB/s eta 0:00:00
# Requirement already satisfied: Flask>=0.9 in /usr/local/lib/python3.9/site-packages (from flask-socketio) (2.3.3)
# Requirement already satisfied: click>=8.1.3 in /usr/local/lib/python3.9/site-packages (from Flask>=0.9->flask-socketio) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in /usr/local/lib/python3.9/site-packages (from Flask>=0.9->flask-socketio) (1.6.2)
# Requirement already satisfied: importlib-metadata>=3.6.0 in /Users/maitreyi/Library/Python/3.9/lib/python/site-packages (from Flask>=0.9->flask-socketio) (6.8.0)
# Requirement already satisfied: Werkzeug>=2.3.7 in /usr/local/lib/python3.9/site-packages (from Flask>=0.9->flask-socketio) (2.3.7)
# Requirement already satisfied: itsdangerous>=2.1.2 in /usr/local/lib/python3.9/site-packages (from Flask>=0.9->flask-socketio) (2.1.2)
# Requirement already satisfied: Jinja2>=3.1.2 in /usr/local/lib/python3.9/site-packages (from Flask>=0.9->flask-socketio) (3.1.2)
# Collecting python-engineio>=4.7.0
#   Downloading python_engineio-4.7.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 1.8 MB/s eta 0:00:00
# Collecting bidict>=0.21.0
#   Downloading bidict-0.22.1-py3-none-any.whl (35 kB)
# Requirement already satisfied: zipp>=0.5 in /Users/maitreyi/Library/Python/3.9/lib/python/site-packages (from importlib-metadata>=3.6.0->Flask>=0.9->flask-socketio) (3.16.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/site-packages (from Jinja2>=3.1.2->Flask>=0.9->flask-socketio) (2.1.3)
# Installing collected packages: python-engineio, bidict, python-socketio, flask-socketio
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
#   DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# Successfully installed bidict-0.22.1 flask-socketio-5.3.6 python-engineio-4.7.0 python-socketio-5.9.0
#
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python3.9 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import Packages

# %%
import os
from dotenv import load_dotenv
load_dotenv(override=True)

import shutil
import sys
sys.path.append('./utils')

### Uncomment below imports as needed -- make sure that all relevant values and keys in the .env file are properly populated
# from utils import redis_helpers
# from utils import helpers
# from utils import language
# from utils import openai_helpers
# from utils import storage
# from utils import bot_helpers

from utils.env_vars import *

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
COG_SEARCH_ENDPOINT
# Out:
# 'https://searchseh000000.search.windows.net'

# %% [markdown]
# ### Activate Cognitive Search Ingestion
# #### First Run - Create Index and Indexer
# ##### Caution: this will destroy any data you might already have in your index

# %%
#### Ingest all knowledge base documents
from utils import cogsearch_helpers

cogsearch_helpers.ingest_kb(container = KB_BLOB_CONTAINER)
# Out:
# Index vec-index Deleted
# Index vec-index created
# Index km-openai Deleted
# Index km-openai created
# Deleted Skillset - km-openai-skills
# Created new Skillset - km-openai-skills
# Deleted Indexer - km-openai-indexer
# Deleted Data Source - km-openai-skills
# Created new Data Source Connection - km-openai-docs
# Created new Indexer - km-openai-indexer
# Running Indexer km-openai-indexer

# %% [markdown]
# #### Additional Runs - Re-indexing with delta documents

# %%
### Re-index additional documents
from utils import cogsearch_helpers

cogsearch_helpers.run_indexer()
# Out:
# Running Indexer km-openai-indexer

# %% [markdown]
# ### Activate Form Recognizer Ingestion

# %%
#### Ingest all form documents

from utils import storage
from utils import fr_helpers

fr_helpers.process_forms(in_container = FR_CONTAINER, out_container = OUTPUT_BLOB_CONTAINER)

# %%
### other containers could be used as the sources of documents to index

cogsearch_helpers.create_indexer('kmoaidemo2') 
cogsearch_helpers.run_indexer()
# Out:
# Deleted Indexer - km-openai-indexer
# Deleted Data Source - km-openai-skills
# Created new Data Source Connection - km-openai-docs
# Created new Indexer - km-openai-indexer
# Running Indexer km-openai-indexer

# %% [markdown]
# ### Scrape Web Pages

# %%
### Scrape data from web pages
### This saves the text from the web pages into the processed folder, and any files which are found are saved
### to the demo folder. For the files to be processed, you need to run the cognitive search re-indexer

# TODO: Some files may be better parsed by form recognizer. Need to decide how to know which is more suitable, 
# and place them in the correct folder. 

# Enter the URLs (only enter the root url, the crawler traverses the hierarchy of the webpages below the root) 
# that you want to scrape in the urls list. Each url should be a string
urls = ['https://www.lufthansa.com']

from utils import web_crawler

for url in urls:
    web_crawler.crawl(url, KB_BLOB_CONN_STR, KB_BLOB_CONTAINER, OUTPUT_BLOB_CONTAINER)
# Out:
# https://www.lufthansa.com
# HTTP Error 403: Forbidden
# HTTP Error 403: Forbidden

# %%
from urllib.parse import urlparse

local_domain = urlparse(url).netloc

# %% [markdown]
# ### Interrogate the APIs with the sample Knowledge Base

# %%
### Use this cell to query Redis with the below queries
import os
import json
from utils import bot_helpers
from dotenv import load_dotenv
load_dotenv(override=True)
from utils import km_agents

from utils import redis_helpers
from utils import openai_helpers
redis_conn = redis_helpers.get_new_conn() 

params_dict = {
    'enable_unified_search': False,
    'enable_redis_search': True,
    'enable_cognitive_search': False,
    'evaluate_step': False,
    'check_adequacy': False,
    'check_intent': False,
    'use_calendar': False,
    'use_bing': False
    }

stream = True

queries = [
    "what is mentioned about the Lost City hotel?",
    "what is mentioned about the Strip in Vegas?",
    "what is mentioned about the Fountain Hotel?"
]

agent_name = 'ccr' # or 'os' or 'zs'

for q in queries:
    agent = km_agents.KMOAI_Agent(agent_name = agent_name, params_dict=params_dict, verbose = False, stream=stream)
    answer, sources, likely_sources, s_id = agent.run(q, redis_conn)
    print("\n\n", answer, '\n', sources, '\n', likely_sources, '\n', s_id, '\n\n\n###############################')

# %% [markdown]
# ### Try out the summarization

# %%
from utils import summarization

folder = './docs_to_summarize/'

ref_summ_df = summarization.summarize_folder(folder, mode='refine', verbose=False)
mp_summ_df  = summarization.summarize_folder(folder, mode='map_reduce', verbose=False)

# %% [markdown]
# ## Experimentation Code Below - NO NEED TO RUN
# ### For your reference only

# %% [markdown]
# ### Reset Redis Index

# %%
#### Reset Index in Redis
from utils import redis_helpers

reset_index = True

if reset_index:
    redis_conn = redis_helpers.get_new_conn()
    redis_helpers.redis_reset_index(redis_conn)

# %% [markdown]
# ### Generate Embeddings and Load into Redis

# %%
### Use this cell to load embeddings directly into Redis from this notebook

import json


emb_documents = []


for item in os.listdir("dump"):
    path = os.path.join("dump", item)

    with open(path, 'r') as openfile:
        data = json.load(openfile)
        
    emb_documents += helpers.generate_embeddings(data, CHOSEN_EMB_MODEL, SMALL_EMB_TOKEN_NUM,  text_suffix = 'S')

    if MEDIUM_EMB_TOKEN_NUM != 0:
        emb_documents += helpers.generate_embeddings(data, CHOSEN_EMB_MODEL, MEDIUM_EMB_TOKEN_NUM, text_suffix = 'M')

    if LARGE_EMB_TOKEN_NUM != 0:
        emb_documents += helpers.generate_embeddings(data, CHOSEN_EMB_MODEL, LARGE_EMB_TOKEN_NUM,  text_suffix = 'L')


helpers.load_embedding_docs_in_redis(emb_documents)

# %%
emb_documents = []

emb_documents += helpers.generate_embeddings_from_json_docs('dump', ADA_002_EMBEDDING_MODEL, ADA_002_MODEL_MAX_TOKENS, text_suffix='XL', limit=-1)

print(f"Generated {len(emb_documents)} embeddings.")
helpers.save_embdding_docs_to_pkl(emb_documents, "test.pkl")

# %%
emb_documents = helpers.load_embedding_docs_from_pkl("test.pkl")
helpers.load_embedding_docs_in_redis(emb_documents)
# Out:
# Loading 141 embeddings into Redis
